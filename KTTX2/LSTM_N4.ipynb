# %%
import keras
from keras import layers

import numpy as np
import random
import io

path = keras.utils.get_file(
    "nietzsche.txt",
    origin="https://s3.amazonaws.com/text-datasets/nietzsche.txt",
)
with io.open(path, encoding="utf-8") as f:
    text = f.read().lower()
text = text.replace("\n", " ")  # We remove newlines chars for nicer display
print("Corpus length:", len(text))

chars = sorted(list(set(text)))
print("Total chars:", len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i : i + maxlen])
    next_chars.append(text[i + maxlen])
print("Number of sequences:", len(sentences))

x = np.zeros((len(sentences), maxlen, len(chars)), dtype="bool")
y = np.zeros((len(sentences), len(chars)), dtype="bool")
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

model = keras.Sequential(
    [
        keras.Input(shape=(maxlen, len(chars))),
        layers.LSTM(128),
        layers.Dense(len(chars), activation="softmax"),
    ]
)
optimizer = keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(loss="categorical_crossentropy", optimizer=optimizer)

def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype("float64")
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

epochs = 40
batch_size = 128

for epoch in range(epochs):
    model.fit(x, y, batch_size=batch_size, epochs=1)
    print()
    print("Generating text after epoch: %d" % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print("...Diversity:", diversity)

        generated = ""
        sentence = text[start_index : start_index + maxlen]
        print('...Generating with seed: "' + sentence + '"')

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.0
            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]
            sentence = sentence[1:] + next_char
            generated += next_char

        print("...Generated: ", generated)
        print("-")
# Out:
# Corpus length: 600893
# Total chars: 56
# Number of sequences: 200285
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 206s 130ms/step - loss: 2.2819
#
# Generating text after epoch: 0
# ...Diversity: 0.2
# ...Generating with seed: " all, he would go "inside." the long and"
# ...Generated:   the sense and consed the some and indersing the sense of the soul ond the sense and the sension of the sense of the strong of the sour in the some in every and inderst and of the some for the worke it is not the such and such a such as the son the sense of the some the contince of the some and inderses of the some what it is the work of the some promed the sense and and send and and are one such
# -
# ...Diversity: 0.5
# ...Generating with seed: " all, he would go "inside." the long and"
# ...Generated:   our the worked the now inder the mankind the worke is its in the doten and hand in and such and in the hights he presert as a serian and inderse of a genered where and beand and the do is nace in as the will sees of the the child the of the desided "no and and appears such of the grathing men manks to the the such the such a condicion to the sens inderst the of then most be and indersisusation of
# -
# ...Diversity: 1.0
# ...Generating with seed: " all, he would go "inside." the long and"
# ...Generated:   comething had skor even ald its peesoring that be of hand alwass  eict s'lencouspes ael aly hadder the appeapo it is the "moring other br read? orde equale we cranther in the hend sight bead! of the earable of modesvind wat it repope its that everysco the  untrouet and caar, the ranch my. the bessenty the helres modelnexnating, god it is a god deven the mo; trate in ake, the soully profeacys; as
# -
# ...Diversity: 1.2
# ...Generating with seed: " all, he would go "inside." the long and"
# ...Generated:   of thats tubent istempudy,ord there an roin thp soficive end; comentant." has its an at lagoum as are she, have the requllews y.  sfirt crimand-maally "wo,n "ord this continger by nature gr bants littionsly handretain canmed thruged gend onlying itherds! that underincluus irn'ate is evprainad stircaid phird apul. sumplaolly charind, lyyowore!.k inde. firith--wadion of hither o1! the blook neilabl
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 195s 125ms/step - loss: 1.6222
#
# Generating text after epoch: 1
# ...Diversity: 0.2
# ...Generating with seed: "of love and goodness in the world to thr"
# ...Generated:  ough the stand of the world and are and and of the stands and articrs to the consting to the world and proptic in the world and the stread to the world as the possible to the stranger and as the stread as the stands to the world as the stands and are are the read to the stands to the world as the strives of the stands to the world are prosish and arting the stands to the world are to the former to
# -
# ...Diversity: 0.5
# ...Generating with seed: "of love and goodness in the world to thr"
# ...Generated:  ough the interpretate the fast men was a some of his inderstands and easily all the power in the position become are love of the right attention and pastical with the masted, the consting and are the well again in itself to his man be power it was become a reversing the dispresis to to so a stain man be would cominatest the there one world as which with the postice of the world, as one with the fi
# -
# ...Diversity: 1.0
# ...Generating with seed: "of love and goodness in the world to thr"
# ...Generated:  istic is beceover as eterfurate teneral encorralts, the law was pain are all,--that na morals the greatess what us abour only valuee th! themselves and their tradie possed musiciusality book the mastedial the recratic cincriences a thden are antinglefules, as to be vivouls therequest to mals" this it hay atteptice to it, with there as of rathes carasileges croy obing to the discrive, when a of tra
# -
# ...Diversity: 1.2
# ...Generating with seed: "of love and goodness in the world to thr"
# ...Generated:  iegers aither novere_--to dadberably were seellemmentarile, to éonkne, the for, evened we me will, for the trus,, mayby, a lanliwition; the workmen", well--to met. -pagienter.=--which qoienced a tact casi-sneet, its kfowleves behjuscive were darke th. genalate cdistes has : he un men??--agorsels.--supeas for the own mthan whyter every not be! are to some artiding itely, to this mixas-havouniedice
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 195s 124ms/step - loss: 1.4962
#
# Generating text after epoch: 2
# ...Diversity: 0.2
# ...Generating with seed: "o do nowadays! in our very democratic, o"
# ...Generated:  ne is a man of the morality of the considered to the individual and morality of the strength the more of man and the strength the morality and man in the state which is a man of the instinction of the senses and in the spirit the simplication of the secret the spirit the really and the find of the morality in the simple the fact the world and the more state is a great and artian and deceive the ar
# -
# ...Diversity: 0.5
# ...Generating with seed: "o do nowadays! in our very democratic, o"
# ...Generated:  f the consiquence of the stand of sense of the artistic of the one in it is a deed it is the christian conscitudless and spiritual in the interposition morally and discover of his strong and simplication and exceation to the morals of the newsle" in every the subvicted in the firmity and is a a more and manifest the stand of the result of morals the seem it is a morality in man is so stated and de
# -
# ...Diversity: 1.0
# ...Generating with seed: "o do nowadays! in our very democratic, o"
# ...Generated:  r of selimition where the the awssincier of the balings of wheines this resence of the most france of premologdy. at the presurtions whe has not be9ne--hamphoundless near ritime. what! at protouren-edated a] devenged; that the synfured a, the peoplers the happiness as has we comparead ruses.  99. bad we chirct the masteral that its this intainted by their dewands the prosectity whatever, the irst
# -
# ...Diversity: 1.2
# ...Generating with seed: "o do nowadays! in our very democratic, o"
# ...Generated:  t of god for among toether, mearing other metimenal then ht we has he furint, and preticising  my furshes! (houghnes much this "cimrufoubleally to this elscious extideses). the isimpled? with a genmusity be if exumplity in e; ask one was the migrtary immonise, is pa.sion. (ze, for impunctear applared, they at themselves beingses, 'cerscience, and from efitedned criale syncees my rim. "poweri-me be
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 207s 132ms/step - loss: 1.4315
#
# Generating text after epoch: 3
# ...Diversity: 0.2
# ...Generating with seed: "es in the mind of the poor man a delusio"
# ...Generated:  n of the sense of the same the same the state of the properarily to the sense of the sense of the stand of the problem of the same the something and and consequently and the specially the something of the superiority of the same the senses to the same something the same to the sense of the same the same the same of the sense of the same belief of the same the sense of the same and instinctive and
# -
# ...Diversity: 0.5
# ...Generating with seed: "es in the mind of the poor man a delusio"
# ...Generated:  n of the satrificies the finger of noting of the delicion of the inscience and experiences when it is now which he least where in the wortholity of which is something the tending the and the source of all the prople to be in the proversions of a live a periodive and and the man and the sand as the superiority and the consequently morality, and and and fact and suffering and out of the spiritual sh
# -
# ...Diversity: 1.0
# ...Generating with seed: "es in the mind of the poor man a delusio"
# ...Generated:  n, and obdiness crute and fact under too being or and too very least if the superflice, in which so thing alvogitical unlear from the fagrerity of themselves bitt, only formial, a porial statings it was masil a every being on angistary outet to thingment subfurity of a new to the delopoes, of them always positifned--and with utuefrian whech =pecting and complates? one moral amoagable -out of bewag
# -
# ...Diversity: 1.2
# ...Generating with seed: "es in the mind of the poor man a delusio"
# ...Generated:  n every matne onch he have, for her adocets and to the uncoseung mike being tle mad.?      perhopse obceine and interbobt adsse" when socaproy the misold manhts fathing and manvent ariement.-to an edficiit: donséit to berood lo'iinly onfet apparines at lartents opeaton hercreath he ir.=--thete." it with then to the protespecuptions axame, groatesly by sace--and time. se-perexpirans with dommlacing
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 207s 132ms/step - loss: 1.3950
#
# Generating text after epoch: 4
# ...Diversity: 0.2
# ...Generating with seed: "s though he had just paid some charming "
# ...Generated:  and self-exception and seems to the problem of the process, the thing of the propresses the strange and the strange the support of the strength and the prople and the strange and sort, and and the strange the strange the prople the considerable the strange the strange of the strong secret the strange and the strange and and self-entition of the strange and solition and soul for the strength and an
# -
# ...Diversity: 0.5
# ...Generating with seed: "s though he had just paid some charming "
# ...Generated:  of this interpretation of the presersation of the there is a preservation of the suctive sentiment the thinker decives and extratives and end of seems when all the demous, and one would be as the thinkers of the great say, the wish the end and what else speaking to in this found of interced the straint for the desires the religions and partical consequence and so decime the and every the strainly
# -
# ...Diversity: 1.0
# ...Generating with seed: "s though he had just paid some charming "
# ...Generated:  right longe soup others in made whereeve the "dicrecome and prevale, ."vaining in shuttaticrses of an sancetic, 6mowally, thk the oppus of the scientify it obserra"--therefore lingle päibli-ive_ in clraus, new sense" intellect-all the platic faseme for cieculy in the wapolity, every pleasly; but who driviliaal far already of the car of i he higholy corrived that is in personst: fals: have power th
# -
# ...Diversity: 1.2
# ...Generating with seed: "s though he had just paid some charming "
# ...Generated:  toom, hum the. a sense) effacely the during in the dief? in that when they concider, inrusional thinkerxman thatever, in fable delesisg punitment and gode. is oveniously our ecrsiphy-c!untm.hthem 3. thus ir not an the univilses. how. that eyov!;" exped exclature. to the real) do! the helteous st3 suppriated the d, the effects of vality, perholene to the sur-evident hove esplai, responsibial to the
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 207s 132ms/step - loss: 1.3755
#
# Generating text after epoch: 5
# ...Diversity: 0.2
# ...Generating with seed: "ulted in the long run, something which h"
# ...Generated:  as all the sense of the subject and developed and some some delight and what is also and a considerated and some standards and some the sense of the spirit of the considerate the possible of the strength the strength and and and also and also a sense of the standard and delight and as also a stands and everything the philosophy of the possible and hand, the considerate and the consequence of the p
# -
# ...Diversity: 0.5
# ...Generating with seed: "ulted in the long run, something which h"
# ...Generated:  e was suffering of state is will perhaps joughe and according the well and a more state the dangerous physical partial and suppeter and well-was care itself consider, the strength and supert, the condition of the english and present in the church some him and the subject to the renony and probably the personality and constitutic stand with which is the higher that it is everything be one with othe
# -
# ...Diversity: 1.0
# ...Generating with seed: "ulted in the long run, something which h"
# ...Generated:  ardlry against the most canntred, has one is ends also understany, the possiblement of new self connotian of the god among them that emotianate, what so consurers. to morality just as right the greek--lo there is no amoty of anothered, "you ke himhel pyilosis apparent the fact the cosebading and the gratical canibativily purenal some cerdouted to thost greex harmmine of all ills for uttent orti"n-
# -
# ...Diversity: 1.2
# ...Generating with seed: "ulted in the long run, something which h"
# ...Generated:  e nobiomon. but as their do the slanivitious apprivabli: whe danss noiscespicating, was starling requestion ence is for certwines the uanian that it was been nains"5" who fway beloog, keawl itself?--all its whil repere life them also, is bornsviliu's, and lowering fell mor, from a pri-olly bisel: the still awound deng different tofd, herfs under their youstioned is their "-futur influences of choi
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 202s 129ms/step - loss: 1.3537
#
# Generating text after epoch: 6
# ...Diversity: 0.2
# ...Generating with seed: "sts and charms higher natures, and more "
# ...Generated:  and consequence is a conscient the prompt and the same thing it is a sublement of the processes and the whole still and the procession and preservation of the conscient and self-constitutely itself and the states and and a conscient in the intellectual interested and the self-centure the states and the spirit the self-concealed the self-centure the self-conscience of the same thing in the most con
# -
# ...Diversity: 0.5
# ...Generating with seed: "sts and charms higher natures, and more "
# ...Generated:  even it is a human states and self the still seems to an ideal in the self-sacticism is and the abore the other some in the power, and it is nature and every the same defined, they have been our own is that it has a sentined men manifested. it was be nations, that is a delight the world, and it is not feel of the fact, the self--which is a pit the whole in the what is in the whole is the concealed
# -
# ...Diversity: 1.0
# ...Generating with seed: "sts and charms higher natures, and more "
# ...Generated:  attemptity between is the proed, in men much bony and the impitates which is above able: a "kind of macon man the suprejurdic compose that onever, will naturally betrie.  espralish, whome goishic former reveges decther men for present, does numbe and so loateness than as reped of imoussely power, fully be world every most depecofted it have, as deed only  weight "will and no impey head in his s-cr
# -
# ...Diversity: 1.2
# ...Generating with seed: "sts and charms higher natures, and more "
# ...Generated:  of the origin is such impuliales.=--times falluigll--traaklative as-sistical frey of throughtugece self-fathgey himself phyself!!..",=men kind an estay anciring. as sanctions. he has some guise, the. nowpeasis. is romatled by a moraling matter pspcruetive upon his vainy, hressy.-plange to abkiabe graats devejodanic blo-divestreng perrorsous bast prifimitful sessimists at least",", which ray here t
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 197s 126ms/step - loss: 1.3319
#
# Generating text after epoch: 7
# ...Diversity: 0.2
# ...Generating with seed: "europeans--of this fact the effect of th"
# ...Generated:  e full the spirit is the subligs the self-and and interpret the same thing the assertion to the present to the same science of the endower and something of the present the serious interpretation of the sense of the present the secrecy of the fact that the same the subliment the sense of the spiritual end, and the strength, the secrecy of the greatest strives of the consciousness of the sense of th
# -
# ...Diversity: 0.5
# ...Generating with seed: "europeans--of this fact the effect of th"
# ...Generated:  e ancient values, as the feeling out of the greater means of the form exercises consciously conception is his own conscious virity has partiful both a feeling the strength, and the perhaps something of the fact, the form the experience of the false of the sympeal and soul of the sense that it was have the most sublial successible endower, if the an exticises of the badmirity of the distain to the
# -
# ...Diversity: 1.0
# ...Generating with seed: "europeans--of this fact the effect of th"
# ...Generated:  as beare and considerable according to these satreable, he is of threey of the error of know him even the herging toochic of wome of his mensable discal kindses perhaps as itself bon an ass, of man is all which many soigult withergote that it is sough, grestene noble is upon the prici--when we as we cause first betawe extic: one learn hanger "bitting an ogd is surruling on at? and philosophy in ro
# -
# ...Diversity: 1.2
# ...Generating with seed: "europeans--of this fact the effect of th"
# ...Generated:  e motives also both brines who he substmenditisator modernous which. , why its rembry--and life often]n of which beholdayeckedous these aspeese unerspiae ittis pocretion vance and language--the enough as imperffut falso, but he ollark or world fose wowar.  re.filous lose of the keppetes with an respectation--how give nocoio, civxe without that bur roverable mouster astection dreads which, human, f
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 192s 123ms/step - loss: 1.3269
#
# Generating text after epoch: 8
# ...Diversity: 0.2
# ...Generating with seed: "ous neurosis--or as i call it, "the reli"
# ...Generated:  gious and source the self-as the experience and self experience of the self-and source the world of the consequently, the word of the problem of the consequently and the most democratic powerful and source of the consequently and own interpret to a sees in a more considerable and self-determine the word and individual of the consequently by form of the self generally in the self and conscience and
# -
# ...Diversity: 0.5
# ...Generating with seed: "ous neurosis--or as i call it, "the reli"
# ...Generated:  gious and appear and interpret of the proper and end, and imparistion of the example, and even in plato in the consequently the formers and one is in it would not the ordinary and emporical concerning of the flut thing in existed and of the to manifull and within one is considerable and intention and the appeard to the most of the favourite of the also the said concerned and one man estervion of t
# -
# ...Diversity: 1.0
# ...Generating with seed: "ous neurosis--or as i call it, "the reli"
# ...Generated:  gious opinion of all knowledge.      ogen. they wishouad him of its conscinct special pathions those uneyed and fame down cloable arrive most more conscience which some powerful--vay, upon in the neighboured, the tanchorce, adrocretious injurled another and doffictly people masterly in a world. this pityer and inspire and seems" and. in what has all what sensh refquitte, what theound more a finded
# -
# ...Diversity: 1.2
# ...Generating with seed: "ous neurosis--or as i call it, "the reli"
# ...Generated:  zitu, privilitius after, him is capacity and time dissenvional purdines perhaps      mojdical value-ppiding anser,ss; nothing by charminally et woll know and rightly both, the world"--this make "inn, ttrouses, with sympathy, so of goad in oils right--recorsed and in pays nearly upresty, here pus essamet:ras? are antiquity, indeescatem as e speciolation--upul. i seet "etict. of exervat lene other s
# -
# 1565/1565 ━━━━━━━━━━━━━━━━━━━━ 193s 123ms/step - loss: 1.3115
#
# Generating text after epoch: 9
# ...Diversity: 0.2
# ...Generating with seed: "the desire for rhythm and dance, for "mu"
# ...Generated:  st responsible to the greatest sense of the sense of the sense of a philosophers the subject of the prophers of the most taste of the belief of a signify and a his problem of the signify and instinct of the prophogen of the most such an ancient and conscious in the sense of the prophers and distrust, and the sense of a sense of the sense of the sense of the former of the profound to the possibilit
# -
# ...Diversity: 0.5
# ...Generating with seed: "the desire for rhythm and dance, for "mu"
# ...Generated:  ch as it is the possibletess itself in itself and experiences is the oberus and prothess of seemed with its fear injury and a become in the present centuries of individual and such an emotion, a philosopher of the transfined which benot become invertion of which the conding the consciousness of the unindividuals the whole man of a the reason itself to make with the the all and soul of even to whic
# -
# ...Diversity: 1.0
# ...Generating with seed: "the desire for rhythm and dance, for "mu"
# ...Generated:  sciers, on, than sopeth, but he has the does notements finagert, and foubles to dues the time individuals of the feelings, amers, which is day. in regined toslimines and who so persons one such possible, be soum--i a us-.its owg? its enough in the glorication thent, and it is souch propounts himself be pringsity in the sighter men"--eitfred, opinionuled,--"accoustion, and who was they has to : thu
# -
# ...Diversity: 1.2
# ...Generating with seed: "the desire for rhythm and dance, for "mu"
# ...Generated:  ster.e the sundeic tredus, cented dogberient to--which early it regard7. covishous extretunets the begreeuz--which my:k strujg of in it", as a man inst inmoral, lends with thos?--the moiber timalers naturecrement as nowadays exmptase life i such, in the aither-unind consequeptler or such workss more, itsteem to kearjes, because the chilogicismx one with hill ahponiiled minded, preval thusour no re
# -
# 1407/1565 ━━━━━━━━━━━━━━━━━━━━ 20s 128ms/step - loss: 1.3052
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-bbc994e8c1a2> in <cell line: 61>()
#      60
#      61 for epoch in range(epochs):
# ---> 62     model.fit(x, y, batch_size=batch_size, epochs=1)
#      63     print()
#      64     print("Generating text after epoch: %d" % epoch)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     318                 for step, iterator in epoch_iterator.enumerate_epoch():
#     319                     callbacks.on_train_batch_begin(step)
# --> 320                     logs = self.train_function(iterator)
#     321                     logs = self._pythonify_logs(logs)
#     322                     callbacks.on_train_batch_end(step, logs)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     831
#     832       with OptionalXlaContext(self._jit_compile):
# --> 833         result = self._call(*args, **kwds)
#     834
#     835       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     876       # In this case we have not created variables on the first call. So we can
#     877       # run the first trace but we should fail if variables are created.
# --> 878       results = tracing_compilation.call_function(
#     879           args, kwds, self._variable_creation_config
#     880       )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py in call_function(args, kwargs, tracing_options)
#     137   bound_args = function.function_type.bind(*args, **kwargs)
#     138   flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139   return function._call_flat(  # pylint: disable=protected-access
#     140       flat_inputs, captured_inputs=function.captured_inputs
#     141   )
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py in _call_flat(self, tensor_inputs, captured_inputs)
#    1320         and executing_eagerly):
#    1321       # No tape is watching; skip to running the function.
# -> 1322       return self._inference_function.call_preflattened(args)
#    1323     forward_backward = self._select_forward_and_backward_functions(
#    1324         args,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_preflattened(self, args)
#     214   def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215     """Calls with flattened tensor inputs and returns the structured output."""
# --> 216     flat_outputs = self.call_flat(*args)
#     217     return self.function_type.pack_output(flat_outputs)
#     218
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py in call_flat(self, *args)
#     249         with record.stop_recording():
#     250           if self._bound_context.executing_eagerly():
# --> 251             outputs = self._bound_context.call_function(
#     252                 self.name,
#     253                 list(args),
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py in call_function(self, name, tensor_inputs, num_outputs)
#    1550     cancellation_context = cancellation.context()
#    1551     if cancellation_context is None:
# -> 1552       outputs = execute.execute(
#    1553           name.decode("utf-8"),
#    1554           num_outputs=num_outputs,
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51   try:
#      52     ctx.ensure_initialized()
# ---> 53     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                         inputs, attrs, num_outputs)
#      55   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
